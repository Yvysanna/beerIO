# %%
# Create pie charts for similar beers to prove validity of our research

# %%
import pandas as pd

# %%
pd.read_csv('data/percentage_beer_data.csv')
# Out:
#            0   abv hex_color  ABV  Min IBU  Max IBU  Astringency       Body  \
# 0          0   5.0    470606  5.0       35       50     5.649718  37.853107
# 1          1   5.2    470606  5.0       35       50     5.649718  37.853107
# 2          2   6.2    F8A600  6.2       20       30    16.447368  17.763158
# 3          3   7.0    CF6900  7.0        5       70     2.395210  37.724551
# 4          4   6.8    DE7C00  6.8       25       45    12.500000  25.000000
# ...      ...   ...       ...  ...      ...      ...          ...        ...
# 21647  21647   5.6       NaN  5.1       18       25    11.594203  15.942029
# 21648  21648   5.8       NaN  5.6       25       50    17.283951  20.987654
# 21649  21649   5.5       NaN  7.5       35       50     6.338028  23.239437
# 21650  21650  11.0       NaN  9.9       50       90     2.173913  43.478261
# 21651  21651   5.6       NaN  4.9       20       40    12.738854  23.566879
#
# ...
