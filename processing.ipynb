# %% [markdown]
# First Processing of already merged data

# %%
import pandas as pd
import os
import json

# %%
jason = pd.read_csv("./data/jdf.csv")
new_df1 = pd.read_csv("./data/new_df1.csv")
new_df2 = pd.read_csv("./data/new_df2.csv")

# %%
jason = jason.reset_index().drop(["index", "Unnamed: 0"], axis=1)

# %%
new_df1.keys()
# Out:
# Index(['Unnamed: 0', 'beer_name', 'key', 'Style', 'Style Key', 'Brewery',
#        'Description', 'ABV', 'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency',
#        'Body', 'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits',
#        'Hoppy', 'Spices', 'Malty'],
#       dtype='object')

# %%
# Remove beers that don't intersect for all 3 datasets
names = set(new_df1.beer_name) & set(new_df2.beer_name) & set(jason.name)
jason = jason[jason.name.isin(names)]

# %%
jason[jason.hex_color.notna()]
# Out:
#           id                         name                  nameDisplay  \
# 6     JPiPQI                   Temptation                   Temptation
# 7     x6bRxw                     Ten FIDY                     Ten FIDY
# 13    zS4jh8  Michelob Golden Draft Light  Michelob Golden Draft Light
# 14    P8CiOe         Michelob Honey Lager         Michelob Honey Lager
# 15    AUl65m               Michelob Light               Michelob Light
# ...      ...                          ...                          ...
# 2257  93XbpS              Chocolate Stout              Chocolate Stout
# 2283  0AvNCe        Grolsch Premium Lager        Grolsch Premium Lager
# 2291  daA1zi         Buster Nut Brown Ale         Buster Nut Brown Ale
# 2292  TpiDMC                Brown Shugga'                Brown Shugga'
# 2297  XybhPj                 Plain Porter                 Plain Porter
#
#                                             description   abv  styleId  \
# 6     Blonde Ale aged in used Chardonnay barrels fro...   7.5    132.0
# 7     Ten FIDY Imperial Stout – This titanic, immens...  10.5     43.0
# 13    Michelob Golden Draft Light, popular in the Mi...   4.1     95.0
# 14    We brew our Michelob Honey Lager with European...   4.9     97.0
# 15    Michelob Light is a full-flavored, rich-tastin...   4.1     94.0
# ...                                                 ...   ...      ...
# 2257  Ebony in color with a rich creamy head. The me...   5.8     44.0
# 2283                                                NaN   5.0     92.0
# 2291  We combined a high school murder-movie sense o...   5.4     12.0
# 2292  How Come you Taste So Good?? Boatloads of Pure...   9.9     29.0
# 2297  A jewel in our crown.  Officially "The Best St...   4.2     23.0
#
#      isOrganic isRetired                                             labels  \
# 6            N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 7            N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 13           N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 14           N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 15           N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# ...        ...       ...                                                ...
# 2257         N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 2283         N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 2291         N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 2292         N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
# 2297         N         N  {'icon': 'https://brewerydb-images.s3.amazonaw...
#
#         status  ... availableId  \
# 6     verified  ...         4.0
# 7     verified  ...         1.0
# 13    verified  ...         1.0
# 14    verified  ...         1.0
# 15    verified  ...         1.0
# ...        ...  ...         ...
# 2257  verified  ...         1.0
# 2283  verified  ...         NaN
# 2291  verified  ...         1.0
# 2292  verified  ...         4.0
# 2297  verified  ...         1.0
#
#                                               available  \
# 6     {'id': 4, 'name': 'Seasonal', 'description': '...
# 7     {'id': 1, 'name': 'Year Round', 'description':...
# 13    {'id': 1, 'name': 'Year Round', 'description':...
# 14    {'id': 1, 'name': 'Year Round', 'description':...
# 15    {'id': 1, 'name': 'Year Round', 'description':...
# ...                                                 ...
# 2257  {'id': 1, 'name': 'Year Round', 'description':...
# 2283                                                NaN
# 2291  {'id': 1, 'name': 'Year Round', 'description':...
# 2292  {'id': 4, 'name': 'Seasonal', 'description': '...
# 2297  {'id': 1, 'name': 'Year Round', 'description':...
#
#                                            foodPairings servingTemperature  \
# 6                                                   NaN                NaN
# 7                                                   NaN                NaN
# 13                                                  NaN               cold
# 14    Turkey Panini, Smoked Thuringer, & Honey-Roast...               cold
# 15                                                  NaN               cold
# ...                                                 ...                ...
# 2257                                                NaN                NaN
# 2283                                                NaN                NaN
# 2291  Great with cured meats, barbecue, red meat, ga...                NaN
# 2292                                                NaN               cool
# 2297                                                NaN                NaN
#
#       servingTemperatureDisplay originalGravity  year  beerVariationId  \
# 6                           NaN           1.062   NaN              NaN
# 7                           NaN             NaN   NaN              NaN
# 13         Cold - (4-7C/39-45F)             NaN   NaN              NaN
# 14         Cold - (4-7C/39-45F)           1.057   NaN              NaN
# 15         Cold - (4-7C/39-45F)             NaN   NaN              NaN
# ...                         ...             ...   ...              ...
# 2257                        NaN             NaN   NaN              NaN
# 2283                        NaN             NaN   NaN              NaN
# 2291                        NaN             NaN   NaN              NaN
# 2292      Cool - (8-12C/45-54F)           1.100   NaN              NaN
# 2297                        NaN             NaN   NaN              NaN
#
#      beerVariation  hex_color
# 6              NaN     FFD878
# 7              NaN     36080A
# 13             NaN     FFD878
# 14             NaN     D77200
# 15             NaN     FFBF42
# ...            ...        ...
# 2257           NaN     000000
# 2283           NaN     FBB123
# 2291           NaN     470606
# 2292           NaN     7B1A00
# 2297           NaN     3F0708
#
# [418 rows x 29 columns]

# %%
data_we_want = ['name', 'description', 'brewery', 'origin', 'rating', 'ABV', 'IBU','astringency', 'body', 'alcohol', 'bitter', 'sweet', 'sour', 'salty', 'fruits', 'hoppy', 'spices', 'malty']
new_df = jason[['name', 'description', 'abv', 'labels', 'hex_color']]

# %%
new_df1.keys()
# Out:
# Index(['Unnamed: 0', 'beer_name', 'key', 'Style', 'Style Key', 'Brewery',
#        'Description', 'ABV', 'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency',
#        'Body', 'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits',
#        'Hoppy', 'Spices', 'Malty'],
#       dtype='object')

# %%
new_df2.keys()
# Out:
# Index(['Unnamed: 0', 'brewery_id', 'brewery_name', 'review_time',
#        'review_overall', 'review_aroma', 'review_appearance',
#        'review_profilename', 'beer_style', 'review_palate', 'review_taste',
#        'beer_name', 'beer_abv', 'beer_beerid'],
#       dtype='object')

# %%
# Merge it all together
new_df = new_df.join(new_df1[['beer_name','Ave Rating', 'Brewery', 'ABV', 'Min IBU', 'Max IBU', 'Astringency',
       'Body', 'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits',
       'Hoppy', 'Spices', 'Malty']].set_index('beer_name'), on='name')
new_df = new_df.join(new_df2[['beer_name', 'beer_style']].set_index('beer_name'), on='name')

# %%
new_df = new_df.drop_duplicates()

# Save it in csv
new_df.to_csv('./data/final_data.csv')

# %%
new_df.keys()
# Out:
# Index(['name', 'description', 'abv', 'labels', 'hex_color', 'Ave Rating',
#        'Brewery', 'ABV', 'Min IBU', 'Max IBU', 'Astringency', 'Body',
#        'Alcohol', 'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits', 'Hoppy',
#        'Spices', 'Malty', 'beer_style'],
#       dtype='object')
